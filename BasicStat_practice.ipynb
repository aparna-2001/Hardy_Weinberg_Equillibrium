# %% [markdown]
# <a href="https://colab.research.google.com/github/aparna-2001/Hardy_Weinberg_Equillibrium/blob/main/BasicStat_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
shortlist = [1,2,3]
sum(shortlist)
# Out:
# 6

# %%
def calculate_mean(numbers):
    s = sum(numbers)
    n = len(numbers)
    mean = s/n

    return mean

shortlist = [1,2,3]
calculate_mean(shortlist)
# Out:
# 2.0
